# %% [markdown]
# # **Project name -  HR Analytics - Predict Employee Attrition**

# %% [markdown]
# ### **Name - Archi Dabhi**

# %% [markdown]
# # **Project Summary -**
#
#
# The HR Employee Attrition dataset provides valuable insights into the factors influencing employee turnover within an organization. The dataset typically includes information such as demographic details (age, gender, marital status), job-related attributes (department, job role, job satisfaction, work-life balance, overtime, income), and organizational factors (environment satisfaction, career growth, distance from home, years at company).
#
# The project aims to:
#
# *    Attrition Trends: Understanding the overall attrition rate, distribution across departments, job roles, and demographic groups to identify high-risk segments.
#
# *   Key Drivers of Attrition: Exploring correlations between attrition and factors such as salary, overtime, work-life balance, job satisfaction, and years of service.
#
# *    Employee Segmentation: Highlighting vulnerable groups such as younger employees, those with high workloads, or employees with low job satisfaction who are more likely to leave.
#
# *   Decision Support: Providing HR managers and organizational leaders with data-driven insights to design retention strategies, improve employee satisfaction, and reduce turnover costs.
#
# This dataset enables the development of an interactive HR Analytics Dashboard, allowing stakeholders to monitor workforce dynamics, track attrition risks, and make informed decisions that strengthen employee engagement and organizational stability.

# %% [markdown]
# ## **Potential Analysis Areas**
#
# * Attrition Rate – Measure the overall percentage of employees leaving the company.
#
# * Demographic Trends – Analyze attrition patterns by age, gender, marital status, and education level.
#
# * Job Role Analysis – Identify which roles or departments experience higher attrition.
#
# * Income & Benefits Impact – Examine the relationship between salary, promotions, and attrition.
#
# * Work-Life Balance & Satisfaction – Explore how work-life balance, job satisfaction, and environment influence attrition.
#
# * Tenure & Experience – Assess whether employee tenure or years at the company affect attrition.
#
# * Performance & Growth Opportunities – Understand if performance ratings, career advancement, or lack of training contribute to attrition.*italicized text*

# %% [markdown]
# ### **Importing the necessary libraries**
# ---
#
# Before working with the dataset, we need to import the required Python libraries.

# %%
# -----------------------------
# Importing Libraries
# -----------------------------

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **1. Loading Dataset**
# ---

# %%
# -----------------------------
# 1. Loading Dataset
# -----------------------------

data = pd.read_csv("HR-Employee-Attrition.csv")
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # **2. Data Exploration**
# ---

# %%
# -----------------------------
# 2. Data Exploration
# ----------------------------

# 1. Print First Rows Of the Data

print("First 5 Rows Of The Data:\n",data.head())
# Out:
# First 5 Rows Of The Data:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %% [markdown]
# ### Checking Dataset Shape
# ---

# %%
# 2. Print Shape -> [Rows and Columns]

print("Dataset Shape (Rows, Columns:\n",data.shape)
# Out:
# Dataset Shape (Rows, Columns:
#  (1470, 35)

# %% [markdown]
# ## Columns Description
# ---
#
# *  Age – Age of the employee.
#
# * Attrition – Target variable; whether the employee left the company (Yes/No).
#
# *  BusinessTravel – Frequency of business travel.
#
# *  Department – Employee’s department.
#
# *  DistanceFromHome – Commute distance.
#
# *  Education – Education level (1–5 scale).
#
# * EducationField – Field of education.
#
# * EnvironmentSatisfaction – Workplace satisfaction (1–4 scale).
#
# * Gender – Gender of the employee.
#
# *  JobInvolvement – Job involvement level (1–4 scale).
#
# *  JobLevel – Position level in company hierarchy.
#
# *  JobRole – Specific role designation.
#
# * JobSatisfaction – Job satisfaction rating (1–4 scale).
#
# *  MaritalStatus – Marital status (Single, Married, Divorced).
#
# *  MonthlyIncome – Monthly salary (important financial factor).
#
# * NumCompaniesWorked – Work history indicator.
#
# * OverTime – Whether the employee works overtime.
#
# * PercentSalaryHike – Last appraisal hike (%).
#
# * PerformanceRating – Employee’s performance rating.
#
# * RelationshipSatisfaction – Satisfaction with workplace relationships (1–4 scale).

# %%
# 3. Print Columns Name

print("Columns Names In The Dataset:")
data.columns.tolist()

# %% [markdown]
# ## Checking Data Types of Dataset Columns
# ---

# %%
# 4. Print Data Types Of Each Columns

print("Data Types Of Each Columns:\n",data.dtypes)
# Out:
# Data Types Of Each Columns:
#  Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# ...

# %% [markdown]
# ## Quick Summary Info
# ---

# %%
# 5. Quick Summary Info

print("Dataset Info:\n",data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ## Statistical Summary of Dataset
# ---

# %%
# 6. Describe statistical info

print("\nStatistical Summary:\n")
print(data.describe(include='all'))
# Out:
# Statistical Summary:
#
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %% [markdown]
# # **3. Data Cleaning & Preprocessing**
# ---
#
# ### Missing Values

# %%
# -----------------------------
# 3. Data Cleaning & Preprocessing
# -----------------------------

#1. Missing values

print("Missing values:\n",data.isnull().sum())
# Out:
# Missing values:
#  Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# ...

# %% [markdown]
# ### Drop Or Filling Missing Values
# ---

# %%
# 2. Drop or fill missing values (example: drop rows with nulls)

print(data.dropna(inplace=True))
# Out:
# None

# %% [markdown]
# ### Duplicate Values
# ---

# %%
# 3. Duplicate Values

print("\nDuplicate Values:\n",data.duplicated().sum())
# Out:
# Duplicate Values:
#  0

# %% [markdown]
# ### Cleaned Dataset
# ---

# %%
# Save cleaned dataset

data.to_csv("HR_Attrition_Updated.csv", index=False)
print("\n Cleaned dataset saved as HR_Attrition_Updated.csv")
# Out:
#  Cleaned dataset saved as HR_Attrition_Updated.csv

# %% [markdown]
# #**4. Univariate Analysis**
# ---
#
# Univariate analysis means analyzing the **distribution of a single variable**.

# %% [markdown]
# ## **What is the most common age range among employees?**
# ---
# ## 4.1 Distribution of Age
#
# We now analyze how the data is distributed across different Age groups of employees.

# %%
# -----------------------------
# 4. Univariate EDA
# -----------------------------

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("HR_Attrition_Updated.csv")


# 4.1 HISTOGRAM BY AGE

plt.figure(figsize=(10, 6))
sns.histplot(x ='Age', data = data, bins = 20 ,kde = True, color = "teal")
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# ## Observation:
#
# * The age distribution is roughly bell-shaped, with most employees concentrated in the 30–40 years range.
#
# * The peak frequency is around 35 years, indicating this is the most common employee age.
#
# * Very few employees are under 22 or above 55, showing that the workforce is primarily mid-career professionals.

# %% [markdown]
# ## **What is the overall distribution of employee attrition in the organization**
# ---
# ## 4.2 Distribution of Attrition
#
#
# We now examine how many employees have left the organization compared to those who stayed, using a pie chart.

# %%
# Pie Chart for Univariate Categorical Column

plt.figure(figsize=(6,6))
data['Attrition'].value_counts().plot.pie(autopct='%1.1f%%', colors=["#26828E", "#3E4989"], startangle=90)
plt.title("Attrition Distribution")
plt.ylabel("")  # remove y-label for clean look
plt.show()

# %% [markdown]
# ## Observation:
#
#
# * About 16.1% of employees have left the organization (Attrition = Yes).
#
# * A majority, 83.9%, have stayed with the organization (Attrition = No).
#
# * This shows that attrition is relatively low, with most employees retained.
#
# * However, the presence of attrition (about 1 in 6 employees) still indicates a notable proportion that HR should pay attention to.

# %% [markdown]
# ## **Which job roles have the highest representation in the company?**
# ---
# ## 4.3 Job Role Distribution
#
# We now analyze the distribution of employees across different job roles.

# %%
# 4.3 Countplot for JobRole

plt.figure(figsize=(10,5))
sns.countplot(y = "JobRole", data = data, order = data["JobRole"].value_counts().index, color = "#35B779")
plt.title("Job Role Counts")
plt.show()

# %% [markdown]
# ## Observation:
#
# * Sales Executives form the largest group with over 320 employees, indicating a strong sales workforce.
#
# * Research Scientists and Laboratory Technicians are also highly represented, suggesting significant focus on R&D.
#
# * Roles such as Human Resources, Research Directors, and Sales Representatives have the least representation (below 100 employees each).
#
# * The company’s workforce is skewed toward sales and research-oriented roles, while managerial and support roles have fewer employees.

# %% [markdown]
# # **5. Bivariate Analysis**
# ---
#
# Bivariate analysis studies the relationship between two variables.

# %% [markdown]
# ## **Which department has the highest employee attrition?**
# ---
# ## 5.1 Attrition by Department
#
# We now analyze the attrition trends across different departments.

# %%
# -----------------------------
# 5. Bivariate EDA
# -----------------------------

# 5.1 Attrition vs Department

plt.figure(figsize=(6,4))
sns.countplot(x='Department', hue='Attrition', data=data, palette= "mako")
plt.title("Attrition by Department")
plt.show()

# %% [markdown]
# ## Observation:
#
# * The Research & Development department shows the highest attrition, followed by Sales.
#
# * The Human Resources department has the least attrition, but also the lowest headcount overall.
#
# * This suggests that attrition is more concentrated in larger departments like R&D and Sales.

# %% [markdown]
# ## **Does working overtime affect employee attrition?**
# ---
# ## 5.2 Attrition by Overtime
#
# We now examine the impact of overtime work on attrition.

# %%
# 5.2 Attrition vs Overtime

plt.figure(figsize=(6,4))
sns.countplot(x='OverTime', hue='Attrition', data=data, palette="viridis")
plt.title("Attrition by Overtime")
plt.show()

# %% [markdown]
# ## Observation:
#
# * Employees who work overtime have a higher attrition count compared to those who don’t.
#
# * This indicates that overtime work is a strong factor influencing attrition, possibly due to burnout or poor work-life balance.

# %% [markdown]
# ## **Does job satisfaction influence employee attrition?**
# ---
#
# ## 5.3 Job Satisfaction by Attrition
# We compare job satisfaction levels of employees who stayed versus those who left.

# %%
# 5.3 JobSatisfaction vs Attrition (violin plot)

plt.figure(figsize=(6,4))
sns.violinplot(x='Attrition', y='JobSatisfaction', data=data, palette="mako")
plt.title("Job Satisfaction by Attrition")
plt.show()

# %% [markdown]
# ## Observation:
#
# * Employees with higher job satisfaction (ratings 3 and 4) are less likely to leave.
#
# * Those with lower satisfaction (ratings 1 and 2) show higher attrition.
#
# * This indicates that job satisfaction plays a critical role in employee retention.

# %% [markdown]
# ## **Does monthly income affect employee attrition?**
# ---
# ## 5.4 Monthly Income by Attrition
# We compare monthly income levels between employees who stayed and those who left.

# %%
# 5.4 MonthlyIncome vs Attrition (boxplot)

plt.figure(figsize=(6,4))
sns.boxplot(x='Attrition', y='MonthlyIncome', data=data, palette="viridis")
plt.title("Monthly Income by Attrition")
plt.show()

# %% [markdown]
# ## Observation:
#
# * Employees who left (Attrition = 1) generally have lower monthly incomes compared to those who stayed.
#
# * Higher income employees (above ~10,000) show very low attrition rates.
#
# * This suggests that salary is a key factor in retaining employees, with lower-paid staff being more likely to leave.

# %% [markdown]
# ## **Handling Outlier**
# ---
# ## 5.4 Monthly Income vs Attrition (Boxplot with Outlier Handling)

# %%
def cap_outliers(x):
    Q1, Q3 = x.quantile([0.25,0.75])
    IQR = Q3 - Q1
    low, up = Q1 - 1.5*IQR, Q3 + 1.5*IQR
    return np.where(x > up, up, np.where(x < low, low, x))

data['MonthlyIncome_cap'] = data.groupby('Attrition')['MonthlyIncome'].transform(cap_outliers)

# Boxplot
sns.boxplot(x='Attrition', y='MonthlyIncome_cap', data=data, palette="viridis")
plt.title("Monthly Income by Attrition (Group-wise Outliers Capped)")
plt.show()

# %% [markdown]
# ## Observation :
#
# * Employees who left (Attrition = Yes) still generally have lower monthly incomes compared to those who stayed.
# * High-income employees (above ~10,000) continue to show very low attrition rates, confirming salary as a key factor in retention.
# * Group-wise outlier capping has **reduced extreme values**, making the distribution within each Attrition group more compact.
# * The median and spread of MonthlyIncome are now clearer, allowing easier comparison between Attrition groups without distortion from outliers.

# %% [markdown]
# # **6. Multivariate Analysis**
#
# Multivariate analysis examines relationships between multiple variables simultaneously to understand patterns, interactions, or impacts in complex data.

# %% [markdown]
# ## **Which employee attributes are most related to each other?**
# ---
# ## 6.1 Correlation Analysis[Heatmap]
#
# We examine the relationships among employee variables using a correlation heatmap.

# %%
# -----------------------------
# 6. Multivariate Analysis
# -----------------------------

# Correlation Heatmap

plt.figure(figsize=(12,6))
corr = data.corr(numeric_only=True)
sns.heatmap(corr, annot=False, cmap="mako", center=0)
plt.title("Correlation Heatmap")
plt.show()

if data['Attrition'].dtype == 'object':
    data['Attrition'] = data['Attrition'].map({'Yes':1,'No':0})

print("Top correlations with Attrition:")
print(data.corr(numeric_only=True)['Attrition'].sort_values(ascending=False).head(10))
# Out:
# Top correlations with Attrition:
# Attrition                  1.000000
# DistanceFromHome           0.077924
# NumCompaniesWorked         0.043494
# MonthlyRate                0.015170
# PerformanceRating          0.002889
# HourlyRate                -0.006846
# EmployeeNumber            -0.010577
# PercentSalaryHike         -0.013478
# Education                 -0.031373
# YearsSinceLastPromotion   -0.033019
# Name: Attrition, dtype: float64

# %% [markdown]
# ## Observation:
#
# * Job Level, Monthly Income, and Total Working Years are strongly correlated.
#
# * Tenure-related variables (Years at Company, Role, Promotion, Manager) are highly interrelated.
#
# * Age correlates moderately with experience and tenure.
#
# * Satisfaction factors show weak correlations, meaning they work independently.

# %% [markdown]
# # **7. Data Encoding & Scaling**
# ---
#
# * Encoding: Converts categorical variables into numeric form (e.g., Attrition Yes/No → 1/0 using Label Encoding, and Department, JobRole → dummy variables using One-Hot Encoding).
#
# * Scaling: Standardizes numerical features (mean = 0, standard deviation = 1) using StandardScaler to ensure all variables are on the same scale, improving model performance.

# %%
# -----------------------------
# 7: Data Encoding & Scaling
# -----------------------------

import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler


le = LabelEncoder()
data['Attrition'] = le.fit_transform(data['Attrition'])

categorical_cols = data.select_dtypes(include='object').columns
df = pd.get_dummies(data, columns=categorical_cols, drop_first=True)


# Separate features & target
X = df.drop('Attrition', axis=1)
y = df['Attrition']


# Scale numeric features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("Completed : Encoding & Scaling done")
# Out:
# Completed : Encoding & Scaling done

# %% [markdown]
# # **8. Train/Test Split & Baseline Model**
# ---
#
# * Train/Test Split: The dataset is divided into training (to train the model)
# and testing sets (to evaluate performance). Typically, 70–80% is used for training and 20–30% for testing.
#
# * Baseline Model: A simple model (like Logistic Regression) is trained first to set a performance benchmark. Later, more complex models can be compared against this baseline.

# %%
# -----------------------------
# 8: Train/Test Split & Baseline Model
# -----------------------------

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

print("Overall class distribution:\n", y.value_counts())


# Split data (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)


model = LogisticRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Heatmap
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',xticklabels=['No', 'Yes'],yticklabels=['No', 'Yes'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix Heatmap")
plt.show()


print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1-score:", f1_score(y_test, y_pred))
# Out:
# Overall class distribution:
#  Attrition
# 0    1233
# 1     237
# Name: count, dtype: int64
# Confusion Matrix:
#  [[237  10]
#  [ 32  15]]
# Accuracy: 0.8571428571428571
# Precision: 0.6
# Recall: 0.3191489361702128
# F1-score: 0.4166666666666667

# %% [markdown]
# # **9. Additional Models & Comparison**
# ---
#
# Train different models (e.g., Logistic Regression, Decision Tree, Random Forest, SVM) and compare their performance using metrics (accuracy, precision, recall, F1). This helps select the best model for the problem.
#
# - **Decision Tree** → A simple model that splits data into rules, making it easy to understand and interpret.
#
# - **Random Forest** → An ensemble of many trees that reduces overfitting and improves accuracy.
#
# - **Cross-Validation** → 5-fold CV provides reliable and unbiased performance estimation.
#
# - **ROC & AUC** → Random Forest shows better discrimination ability with higher AUC and accuracy

# %%
# -----------------------------
# 9: Additional Models & Comparison
# -----------------------------

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# --- Decision Tree ---

dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
print("Decision Tree Report:\n", classification_report(y_test, y_pred_dt))

# --- Random Forest ---

rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Random Forest Report:\n", classification_report(y_test, y_pred_rf))

# --- Cross-validation ---

cv_dt = cross_val_score(dt, X_scaled, y, cv=5).mean()
cv_rf = cross_val_score(rf, X_scaled, y, cv=5).mean()
print("CV Decision Tree:", cv_dt)
print("CV Random Forest:", cv_rf)

# --- ROC Curve ---

y_prob_dt = dt.predict_proba(X_test)[:,1]
y_prob_rf = rf.predict_proba(X_test)[:,1]

fpr_dt, tpr_dt, _ = roc_curve(y_test, y_prob_dt)
fpr_rf, tpr_rf, _ = roc_curve(y_test, y_prob_rf)

plt.plot(fpr_dt, tpr_dt, label="Decision Tree (AUC = %.2f)" % roc_auc_score(y_test, y_prob_dt))
plt.plot(fpr_rf, tpr_rf, label="Random Forest (AUC = %.2f)" % roc_auc_score(y_test, y_prob_rf))
plt.plot([0,1],[0,1],'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()
# Out:
# Decision Tree Accuracy: 0.8095238095238095
# Decision Tree Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       247
#            1       0.40      0.40      0.40        47
#
#     accuracy                           0.81       294
#    macro avg       0.65      0.65      0.65       294
# weighted avg       0.81      0.81      0.81       294
#
# Random Forest Accuracy: 0.8299319727891157
# Random Forest Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91       247
#            1       0.36      0.09      0.14        47
#
#     accuracy                           0.83       294
#    macro avg       0.61      0.53      0.52       294
# weighted avg       0.77      0.83      0.78       294
#
# CV Decision Tree: 0.7836734693877551
# CV Random Forest: 0.8598639455782312

# %% [markdown]
# # **10. Model Selection & Tuning**
# ---
#
# The process of finding the best hyperparameters (settings) for a model using methods like GridSearchCV with cross-validation to improve performance and reliability.

# %%
# -----------------------------
# 10: Model Selection & Tuning
# -----------------------------

from sklearn.model_selection import GridSearchCV

# Define grid
param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [None, 5, 10, 20],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4]
}

grid_search = GridSearchCV(RandomForestClassifier(random_state=42),
                           param_grid,
                           cv=5,
                           scoring='accuracy',
                           n_jobs=-1,
                           verbose=2)

grid_search.fit(X_train, y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best CV Score:", grid_search.best_score_)

# Evaluate best model
best_rf = grid_search.best_estimator_
y_pred_best = best_rf.predict(X_test)

print("Tuned Random Forest Accuracy:", accuracy_score(y_test, y_pred_best))
print("Tuned Random Forest Report:\n", classification_report(y_test, y_pred_best))
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Best CV Score: 0.8639523981247746
# Tuned Random Forest Accuracy: 0.8299319727891157
# Tuned Random Forest Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91       247
#            1       0.33      0.06      0.11        47
#
#     accuracy                           0.83       294
#    macro avg       0.59      0.52      0.51       294
# weighted avg       0.76      0.83      0.78       294

# %% [markdown]
# # **11. Explainability with SHAP**
#
# SHAP shows **how each feature impacts the model’s predictions**, using **dot and bar plots** to display feature importance and effect.

# %%
# -----------------------------
# 11: Explainability with SHAP
# -----------------------------


from sklearn.ensemble import RandomForestClassifier
import shap


best_rf = RandomForestClassifier(random_state=42)
best_rf.fit(X_train, y_train)

# SHAP
explainer = shap.TreeExplainer(best_rf)
shap_values = explainer.shap_values(X_test)

# For binary classification
if isinstance(shap_values, list):
    shap_values = shap_values[1]

shap.summary_plot(shap_values, X_test, feature_names=X.columns)
shap.summary_plot(shap_values, X_test, feature_names=X.columns, plot_type="bar")

# %% [markdown]
# # **Conclusion**
#
# This project successfully analyzed employee attrition using data-driven insights and machine learning. Key factors influencing attrition include overtime, income, tenure, and job satisfaction. The best-performing model achieved strong predictive accuracy and SHAP analysis confirmed the importance of these drivers. These findings provide actionable guidance for targeted retention strategies and establish a foundation for ongoing monitoring and model improvement.
